# %%
from wxauto import WeChat

# 初始化微信客户端
wx = WeChat()

# 设置要发送的消息
message = "大家好，这里是机器人"

# 发送给指定好友（替换为好友的备注或昵称）
# friend_name = "WR"  # ⚠️ 修改这里
# wx.ChatWith(friend_name)    # 切换到好友聊天窗口
# for i in range(3):         # 循环发送10条消息
#     wx.SendMsg(message)     # 发送消息
#     time.sleep(1)           # 等待1秒，避免发送过快

# 发送给指定群（替换为群名称）
group_name = "李明泽-德纳集团"        # ⚠️ 修改这里
wx.ChatWith(group_name)     # 切换到群聊天窗口
for i in range(10):         # 循环发送10条消息
    wx.SendMsg(message)     # 发送消息
    time.sleep(0.5)           # 等待1秒，避免发送过快


print("消息发送完成！")
# Out:
# 初始化成功，获取到已登录窗口：清邈.
# 消息发送完成！
