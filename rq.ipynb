# %%
import rqdatac as rq
rq.init('user_538308','Y3F7sbyq**##')

# %%
rq.futures.get_dominant('IF', '20160801')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationFailed                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rq.futures.get_dominant('IF', '20160801')
#
# File c:\Users\wr\AppData\Local\Programs\Python\Python312\Lib\site-packages\rqdatac\services\future.py:85, in get_dominant(underlying_symbol, start_date, end_date, rule, rank, market)
#      82 elif start_date:
#      83     end_date = start_date
# ---> 85 result = get_client().execute(
#      86     "futures.get_dominant_v2", underlying_symbol, start_date, end_date, rule, rank, market=market)
#      88 if not result:
#      89     return
#
# File c:\Users\wr\AppData\Local\Programs\Python\Python312\Lib\site-packages\rqdatac\decorators.py:65, in retry.<locals>.decorate.<locals>.wrap(*args, **kwargs)
#      63 while c > 0:
#      64     try:
# ---> 65         return func(*args, **kwargs)
#      66     except suppress_exceptions as e:
#      67         c -= 1
# ...
