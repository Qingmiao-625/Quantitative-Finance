# %%
from xtquant import xtdata

xtdata.connect()
res = xtdata.get_full_tick(['BU888'])
print("最新tick数据：", res)
# Out:
# xtquant文档地址：http://dict.thinktrader.net/nativeApi/start_now.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 from xtquant import xtdata
# ----> 3 xtdata.connect()
#       4 res = xtdata.get_full_tick(['BU888'])
#       5 print("最新tick数据：", res)
#
# File c:\Users\wr\AppData\Local\Programs\Python\Python312\Lib\site-packages\xtquant\xtdata.py:137, in connect(ip, port, remember_if_success)
#     134 __client = xtconn.connect_any(server_list, start_port, end_port)
#     136 if not __client or not __client.is_connected():
# --> 137     raise Exception("无法连接xtquant服务，请检查QMT-投研版或QMT-极简版是否开启")
#     139 if remember_if_success:
#     140     global __client_last_spec
#
# Exception: 无法连接xtquant服务，请检查QMT-投研版或QMT-极简版是否开启

# %%
a=xtdata.download_history_data2(['000001.SZ'],period="1m",start_time='2023-01-01',end_time='2023-01-02')
a

# %%
xtdata.get_his_st_data('000001.SZ')
# Out:
# {}

# %%
import yfinance as yf
data = yf.download('CL=F',start='2022-01-01',end='2023-01-01')
data.head()
# Out:
# C:\Users\wr\AppData\Local\Temp\ipykernel_13640\3373800751.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('CL=F',start='2022-01-01',end='2023-01-01')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CL=F']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, CL=F), (Close, CL=F), (High, CL=F), (Low, CL=F), (Open, CL=F), (Volume, CL=F)]
# Index: []

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key="B6L9PDYHHGGSC0CV")
data= ts.get_intraday(symbol='IBM',interval='1min', outputsize='full')
data
len(data[0])
# Out:
# 13707

# %%
# save data into a csv file
import numpy as np
import pandas as pd
dict=data[0]
dict = pd.DataFrame(dict)
dict.to_csv('data/data.csv', index=False)

# %%
dict
# Out:
#           2025-07-09 19:47:00 2025-07-09 19:40:00 2025-07-09 19:39:00  \
# 1. open              290.1900            290.2000            290.2000
# 2. high              290.1900            290.2000            290.2000
# 3. low               290.1900            290.2000            290.2000
# 4. close             290.1900            290.2000            290.2000
# 5. volume                   1                   5                   3
#
#           2025-07-09 19:38:00 2025-07-09 19:34:00 2025-07-09 19:33:00  \
# 1. open              290.0000            290.2000            290.1600
# 2. high              290.0000            290.2000            290.1600
# 3. low               290.0000            290.2000            290.1600
# 4. close             290.0000            290.2000            290.1600
# 5. volume                   1                  10                   1
#
#           2025-07-09 19:28:00 2025-07-09 19:26:00 2025-07-09 19:25:00  \
# ...

# %%
from binance.client import Client
import pandas as pd

client = Client()  # 公开API无需密钥
klines = client.get_historical_klines(
    symbol="BTCUSDT",
    interval=Client.KLINE_INTERVAL_1HOUR,
    start_str="2023-01-01",
    end_str="2023-01-02"
)

# 转换为DataFrame
df = pd.DataFrame(klines, columns=[
    'Open time', 'Open', 'High', 'Low', 'Close', 'Volume',
    'Close time', 'Quote volume', 'Trades',
    'Taker buy base', 'Taker buy quote', 'Ignore'
])
df['Open time'] = pd.to_datetime(df['Open time'], unit='ms')
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 from binance.client import Client
#       2 import pandas as pd
# ----> 4 client = Client()  # 公开API无需密钥
#       5 klines = client.get_historical_klines(
#       6     symbol="BTCUSDT",
#       7     interval=Client.KLINE_INTERVAL_1HOUR,
#       8     start_str="2023-01-01",
#       9     end_str="2023-01-02"
#      10 )
#      12 # 转换为DataFrame
#
# File c:\Users\wr\AppData\Local\Programs\Python\Python312\Lib\site-packages\binance\client.py:51, in Client.__init__(self, api_key, api_secret, requests_params, tld, base_endpoint, testnet, private_key, private_key_pass, ping, time_unit)
#      49 # init DNS and SSL cert
#      50 if ping:
# ---> 51     self.ping()
#
# File c:\Users\wr\AppData\Local\Programs\Python\Python312\Lib\site-packages\binance\client.py:344, in Client.ping(self)
# ...
